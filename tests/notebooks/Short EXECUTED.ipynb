# %% [markdown]
# # Short Test Notebook

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10, 30))
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.021493  0.759179  0.236436  0.999756  0.281724  0.854162  0.706743
# 1  0.554080  0.574277  0.037474  0.555891  0.054811  0.616335  0.494027
# 2  0.949009  0.021540  0.300131  0.868649  0.781918  0.559734  0.264474
# 3  0.285539  0.809967  0.958009  0.550439  0.764069  0.422616  0.780399
# 4  0.774296  0.644231  0.015609  0.428782  0.532900  0.381251  0.716289
# 5  0.136624  0.474772  0.909870  0.396314  0.464431  0.002111  0.835830
# 6  0.107564  0.151257  0.566055  0.076924  0.865520  0.686528  0.773273
# 7  0.498028  0.690166  0.764919  0.865398  0.875135  0.196722  0.034897
# 8  0.549101  0.664838  0.839909  0.302491  0.812938  0.902592  0.362766
# 9  0.061258  0.456964  0.192640  0.297920  0.943749  0.549754  0.667768
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.542841  0.096447  0.398650  ...  0.558577  0.160900  0.975375  0.544873
# ...

# %% [markdown]
# ## Image
#
# ![](media/ss.png)

# %%
df.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col1 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col4 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col5 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_96f9a3d4_c83d_11ea_8fa9_b8e85647e68crow0_col6 {
#             background-color:  #046097;
#             color:  #f1f1f1;
# ...
