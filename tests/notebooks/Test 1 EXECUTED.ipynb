# %% [markdown]
# # Test_1 Notebook
#
# In this notebook, we test the dataframe_image package conversion.
#
# ## Markdown tables
#
# asdfas salfj asdf
# asflkajsfd
#
# ### Business Problem
#
# In Retail and E-Commerce (B2C), but also more broadly in B2B, a key element in shaping the business strategy of the firm would be the knowledge around customer behaviour.
#
# #### Stakeholders or Interested Parties
#
# This would be useful to the following teams within a firm
# 1. **Product/Services**
# Products selling more than others, would be an opportunity to evaluate the product offering or improve specific products.
#
#
# 2. **Operations/Logistics**
# From stock management perspective, understanding which products are in demand would reduce storage costs and improve delivery/logistics operations
#
# 3. **Marketing**
# Understanding of the customer segmenets would allow for more effective marketing of some of the products to specific segments, or perhaps with little variations depending on the segment
#
# ---
#
# asdfasf
# asfdas
# fsadfa
#
# ### Goal
# Purpose of this project is to develop a system to
#
# * Capture key business metrics (KPIs) measuring customer behaviour related to Transactions and Products
# * Identify and group customer segments using Recency, Frequency, Monetary Value (RFM) approach
#
# #### Data Set
#
# Online Retail Data Set
# http://archive.ics.uci.edu/ml/datasets/online+retail
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
#
#
# **Key Attributes information**
#
# | Attribute Name | Summary | Description |
# |:---|:---|:---|
# | **InvoiceNo** | Invoice number| Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation |
# | **StockCode** | Product (item) code | Nominal, a 5-digit integral number uniquely assigned to each distinct product |
# | **Description** | Product (item) name| Nominal |
# | **Quantity** | The quantities of each product (item) per transaction | Numeric |
# | **InvoiceDate** | Invice Date and time | Numeric, the day and time when each transaction was generated |
# | **UnitPrice** | Unit price | Numeric, Product price per unit in sterling |
# | **CustomerID** | Customer number | Nominal, a 5-digit integral number uniquely assigned to each customer |
# | **Country** | Country name | Nominal, the name of the country where each customer resides |
#
# #### Key Metrics and othe KPIs
#
#
# 1. Monthly Revenue & Revenue Rate
# 2. Monthly Active Customer
# 3. Monthly Order Count
#
#
# #### Project Planning & Key Milestones
#
#
# | Milestones | Weeks | Sprints | Key Tasks | Dates |
# |:---|:---|:---|:---|:---|
# | Proposal Draft | 1-2 | 1 | 1. Research on various project themes<br>2. Project Summary<br>3. Goals and Objectives<br>4. Dataset summary | 6th Jan - 17th Jan |
# | Initial Project Brief | 3-4 | 2 | 1. Initial analysis & next steps<br>2. Basic EDA and visualizations<br>3. Understanding key metrics and features | 20th Jan - 31st Jan |
# | Initial Findings | 5-6 | 3 | 1. Data processing<br>2. Full EDA & Feature selection<br>3. Core Data Science modelling, validation and testing | 3rd Feb - 14th Feb |
# | Final Findings | 7 | 4 | 1. Final parameter tuning and model selection<br>2. Tidying up code and reports<br>3. Technical Notebook submission | 17th Feb - 21st Feb |
# | Presentation | 8 | 4 | 1. Presentation write up and Submission | 24th Feb - 26th Feb |
#
# #### test section after image
#
# asf

# %% [markdown]
# ## Reference markdown image
#
# First we have a reference markdown image
#
# ![][1]
#
# Some random text here
#
# [1]: media/ss.png

# %% [markdown]
# ## Inline markdown image
#
# Same image using inline markdown syntax.
#
# ![](media/ss.png)
#
# random text here

# %% [markdown]
# ## Single attachment
#
# Testing a single image "attachment". Done by dragging and dropping an image in a markdown cell in edit mode.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Multiple Attachments
#
# ![falls.png](attachment:falls.png)
#
# #### Second attachment
#
# ![water.png](attachment:water.png)

# %% [markdown]
# ## Inline web image
#
# ![](https://c402277.ssl.cf1.rackcdn.com/photos/14206/images/hero_full/WW187785.jpg)

# %% [markdown]
# ### HTML Image tags
#
# Local image
#
# <img src="media/ss.png"/>
#
# web image
#
# <img src="https://kajabi-storefronts-production.global.ssl.fastly.net/kajabi-storefronts-production/themes/1033380/settings_images/NyrRjGSTnWKumhv2A6X6_gray_and_green_only.png"/>

# %% [markdown]
# ## Gifs
#
# ![](media/covid19.gif)

# %% [markdown]
# ## Pandas DataFrames

# %%
import pandas as pd

df = pd.read_csv("data/covid19.csv", index_col="date", parse_dates=["date"])
df.tail()
# Out:
#              China      USA    Italy       UK    Iran    Spain
# date
# 2020-04-18  4636.0  38671.0  23227.0  15498.0  5031.0  20043.0
# 2020-04-19  4636.0  40664.0  23660.0  16095.0  5118.0  20453.0
# 2020-04-20  4636.0  42097.0  24114.0  16550.0  5209.0  20852.0
# 2020-04-21  4636.0  44447.0  24648.0  17378.0  5297.0  21282.0
# 2020-04-22  4636.0  46628.0  25085.0  18151.0  5391.0  21717.0

# %% [markdown]
# ## Multiple dataframes and other output in one cell

# %%
from IPython.display import display

print("here")
print("there")
display(df.head())
display(df.iloc[10:20])
df.iloc[25:33]
# Out:
# here
# there
#              China  USA  Italy  UK  Iran  Spain
# date
# 2020-02-26  2717.0  NaN   12.0 NaN  19.0    NaN
# 2020-02-27  2746.0  NaN   17.0 NaN  26.0    NaN
# 2020-02-28  2790.0  NaN   21.0 NaN  34.0    NaN
# 2020-02-29  2837.0  1.0   29.0 NaN  43.0    NaN
# 2020-03-01  2872.0  1.0   34.0 NaN  54.0    NaN
#              China   USA   Italy    UK   Iran  Spain
# date
# 2020-03-07  3072.0  17.0   233.0   2.0  145.0   10.0
# 2020-03-08  3100.0  21.0   366.0   3.0  194.0   17.0
# 2020-03-09  3123.0  22.0   463.0   4.0  237.0   28.0
# 2020-03-10  3139.0  28.0   631.0   6.0  291.0   35.0
# 2020-03-11  3161.0  32.0   827.0   8.0  354.0   54.0
# 2020-03-12  3172.0  40.0  1000.0   8.0  429.0   55.0
# 2020-03-13  3180.0  48.0  1266.0   8.0  514.0  133.0
# 2020-03-14  3193.0  54.0  1441.0  21.0  611.0  195.0
# 2020-03-15  3203.0  60.0  1809.0  21.0  724.0  289.0
# 2020-03-16  3217.0  84.0  2158.0  56.0  853.0  342.0
#              China     USA    Italy      UK    Iran   Spain
# date
# 2020-03-22  3274.0   427.0   5476.0   282.0  1685.0  1772.0
# 2020-03-23  3274.0   552.0   6077.0   336.0  1812.0  2311.0
# 2020-03-24  3281.0   706.0   6820.0   423.0  1934.0  2808.0
# 2020-03-25  3285.0   943.0   7503.0   466.0  2077.0  3647.0
# 2020-03-26  3291.0  1210.0   8215.0   580.0  2234.0  4365.0
# 2020-03-27  3296.0  1582.0   9134.0   761.0  2378.0  5138.0
# 2020-03-28  3299.0  2182.0  10023.0  1021.0  2517.0  5982.0
# 2020-03-29  3304.0  2566.0  10779.0  1231.0  2640.0  6803.0

# %% [markdown]
# ### Styled pandas dataframes

# %%
df.tail().style.highlight_max()
# Out:
# <style type="text/css">
# #T_5c3cf_row0_col0, #T_5c3cf_row1_col0, #T_5c3cf_row2_col0, #T_5c3cf_row3_col0, #T_5c3cf_row4_col0, #T_5c3cf_row4_col1, #T_5c3cf_row4_col2, #T_5c3cf_row4_col3, #T_5c3cf_row4_col4, #T_5c3cf_row4_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5c3cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c3cf_level0_col0" class="col_heading level0 col0" >China</th>
#       <th id="T_5c3cf_level0_col1" class="col_heading level0 col1" >USA</th>
#       <th id="T_5c3cf_level0_col2" class="col_heading level0 col2" >Italy</th>
#       <th id="T_5c3cf_level0_col3" class="col_heading level0 col3" >UK</th>
#       <th id="T_5c3cf_level0_col4" class="col_heading level0 col4" >Iran</th>
#       <th id="T_5c3cf_level0_col5" class="col_heading level0 col5" >Spain</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c3cf_level0_row0" class="row_heading level0 row0" >2020-04-18 00:00:00</th>
#       <td id="T_5c3cf_row0_col0" class="data row0 col0" >4636.000000</td>
#       <td id="T_5c3cf_row0_col1" class="data row0 col1" >38671.000000</td>
#       <td id="T_5c3cf_row0_col2" class="data row0 col2" >23227.000000</td>
#       <td id="T_5c3cf_row0_col3" class="data row0 col3" >15498.000000</td>
#       <td id="T_5c3cf_row0_col4" class="data row0 col4" >5031.000000</td>
#       <td id="T_5c3cf_row0_col5" class="data row0 col5" >20043.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3cf_level0_row1" class="row_heading level0 row1" >2020-04-19 00:00:00</th>
#       <td id="T_5c3cf_row1_col0" class="data row1 col0" >4636.000000</td>
#       <td id="T_5c3cf_row1_col1" class="data row1 col1" >40664.000000</td>
#       <td id="T_5c3cf_row1_col2" class="data row1 col2" >23660.000000</td>
#       <td id="T_5c3cf_row1_col3" class="data row1 col3" >16095.000000</td>
#       <td id="T_5c3cf_row1_col4" class="data row1 col4" >5118.000000</td>
#       <td id="T_5c3cf_row1_col5" class="data row1 col5" >20453.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3cf_level0_row2" class="row_heading level0 row2" >2020-04-20 00:00:00</th>
#       <td id="T_5c3cf_row2_col0" class="data row2 col0" >4636.000000</td>
#       <td id="T_5c3cf_row2_col1" class="data row2 col1" >42097.000000</td>
#       <td id="T_5c3cf_row2_col2" class="data row2 col2" >24114.000000</td>
#       <td id="T_5c3cf_row2_col3" class="data row2 col3" >16550.000000</td>
#       <td id="T_5c3cf_row2_col4" class="data row2 col4" >5209.000000</td>
#       <td id="T_5c3cf_row2_col5" class="data row2 col5" >20852.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3cf_level0_row3" class="row_heading level0 row3" >2020-04-21 00:00:00</th>
#       <td id="T_5c3cf_row3_col0" class="data row3 col0" >4636.000000</td>
#       <td id="T_5c3cf_row3_col1" class="data row3 col1" >44447.000000</td>
#       <td id="T_5c3cf_row3_col2" class="data row3 col2" >24648.000000</td>
#       <td id="T_5c3cf_row3_col3" class="data row3 col3" >17378.000000</td>
#       <td id="T_5c3cf_row3_col4" class="data row3 col4" >5297.000000</td>
#       <td id="T_5c3cf_row3_col5" class="data row3 col5" >21282.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3cf_level0_row4" class="row_heading level0 row4" >2020-04-22 00:00:00</th>
#       <td id="T_5c3cf_row4_col0" class="data row4 col0" >4636.000000</td>
#       <td id="T_5c3cf_row4_col1" class="data row4 col1" >46628.000000</td>
#       <td id="T_5c3cf_row4_col2" class="data row4 col2" >25085.000000</td>
#       <td id="T_5c3cf_row4_col3" class="data row4 col3" >18151.000000</td>
#       <td id="T_5c3cf_row4_col4" class="data row4 col4" >5391.000000</td>
#       <td id="T_5c3cf_row4_col5" class="data row4 col5" >21717.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matplotlib images

# %%
df.plot();

# %% [markdown]
# ### Huge dfs

# %%
df.sample(25, axis=1, replace=True).head(10)
# Out:
#              Iran  Italy   USA  Spain  Italy  Spain   USA   UK   Iran  Italy  \
# date
# 2020-02-26   19.0   12.0   NaN    NaN   12.0    NaN   NaN  NaN   19.0   12.0
# 2020-02-27   26.0   17.0   NaN    NaN   17.0    NaN   NaN  NaN   26.0   17.0
# 2020-02-28   34.0   21.0   NaN    NaN   21.0    NaN   NaN  NaN   34.0   21.0
# 2020-02-29   43.0   29.0   1.0    NaN   29.0    NaN   1.0  NaN   43.0   29.0
# 2020-03-01   54.0   34.0   1.0    NaN   34.0    NaN   1.0  NaN   54.0   34.0
# 2020-03-02   66.0   52.0   6.0    NaN   52.0    NaN   6.0  NaN   66.0   52.0
# 2020-03-03   77.0   79.0   7.0    1.0   79.0    1.0   7.0  NaN   77.0   79.0
# 2020-03-04   92.0  107.0  11.0    2.0  107.0    2.0  11.0  NaN   92.0  107.0
# 2020-03-05  107.0  148.0  12.0    3.0  148.0    3.0  12.0  1.0  107.0  148.0
# 2020-03-06  124.0  197.0  14.0    5.0  197.0    5.0  14.0  2.0  124.0  197.0
#
#             ...   UK   USA  Spain   Iran  Spain  Spain   China  Italy  Italy  \
# date        ...
# 2020-02-26  ...  NaN   NaN    NaN   19.0    NaN    NaN  2717.0   12.0   12.0
# 2020-02-27  ...  NaN   NaN    NaN   26.0    NaN    NaN  2746.0   17.0   17.0
# 2020-02-28  ...  NaN   NaN    NaN   34.0    NaN    NaN  2790.0   21.0   21.0
# 2020-02-29  ...  NaN   1.0    NaN   43.0    NaN    NaN  2837.0   29.0   29.0
# 2020-03-01  ...  NaN   1.0    NaN   54.0    NaN    NaN  2872.0   34.0   34.0
# 2020-03-02  ...  NaN   6.0    NaN   66.0    NaN    NaN  2914.0   52.0   52.0
# 2020-03-03  ...  NaN   7.0    1.0   77.0    1.0    1.0  2947.0   79.0   79.0
# 2020-03-04  ...  NaN  11.0    2.0   92.0    2.0    2.0  2983.0  107.0  107.0
# 2020-03-05  ...  1.0  12.0    3.0  107.0    3.0    3.0  3015.0  148.0  148.0
# 2020-03-06  ...  2.0  14.0    5.0  124.0    5.0    5.0  3044.0  197.0  197.0
#
#              Iran
# date
# 2020-02-26   19.0
# 2020-02-27   26.0
# 2020-02-28   34.0
# 2020-02-29   43.0
# 2020-03-01   54.0
# 2020-03-02   66.0
# 2020-03-03   77.0
# 2020-03-04   92.0
# 2020-03-05  107.0
# 2020-03-06  124.0
#
# [10 rows x 25 columns]

# %%
ax = df.plot()
ax
# Out:
# <AxesSubplot:xlabel='date'>

# %%
ax.figure

# %% [markdown]
# ## dataframe with LaTeX

# %%
df_latex = pd.DataFrame(['$\int^0_1 3x^2 dx$'])
df_latex
# Out:
#                     0
# 0  $\int^0_1 3x^2 dx$
